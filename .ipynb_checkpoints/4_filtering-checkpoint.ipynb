# %%
import pandas as pd

df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent') #change the index to selected column
df_schema = pd.read_csv('data/survey_results_schema.csv', index_col='Column')
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.loc[1]
# Out:
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# DevType                                                                 NaN
# ...

# %%
df_schema.head()
# Out:
#                                                     QuestionText
# Column
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# BetterLife     Do you think people born today will have a bet...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BlockchainOrg  How is your organization thinking about or imp...

# %%
df_schema.loc['SOJobs']
# Out:
# QuestionText    Have you ever used or visited Stack Overflow J...
# Name: SOJobs, dtype: object

# %%
df_schema.loc['SOJobs', 'QuestionText'] #to see full text
# Out:
# 'Have you ever used or visited Stack Overflow Jobs?'

# %%
df_schema.sort_index(inplace=True) #sorted alfabeticly, to reverse add flad ascending=False

# %%
df_schema.head()
# Out:
#                                                     QuestionText
# Column
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# BetterLife     Do you think people born today will have a bet...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BlockchainOrg  How is your organization thinking about or imp...

# %%
df.head(3)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
# 3                             Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# ...

# %%
df_schema
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
df_schema.loc['ConvertedComp', 'QuestionText']
# Out:
# 'Salary converted to annual USD salaries using the exchange rate on 2019-02-01, assuming 12 working months and 50 working weeks.'

# %%
high_salary = (df['ConvertedComp'] > 120_000)
df.loc[high_salary, ['ConvertedComp', 'UndergradMajor', 'Country', 'LanguageWorkedWith']]
# Out:
#             ConvertedComp                                     UndergradMajor  \
# Respondent
# 6                366420.0                          Mathematics or statistics
# 16               455352.0                                                NaN
# 32              1100000.0  Information systems, information technology, o...
# 39               156000.0  Computer science, computer engineering, or sof...
# 45               175000.0  Another engineering discipline (ex. civil, ele...
# ...                   ...                                                ...
# 88874           2000000.0  A social science (ex. anthropology, psychology...
# 88876            180000.0  Computer science, computer engineering, or sof...
# 88877           2000000.0  Computer science, computer engineering, or sof...
# 88878            130000.0  Computer science, computer engineering, or sof...
# 88882            588012.0  Computer science, computer engineering, or sof...
#
# ...

# %%
countries = ['Poland', 'Ukraine', 'Belarus', 'Russia', 'Germany'] 
filt = (df['Country'].isin(countries)) & (df['ConvertedComp'] < 150_000) & (df['ConvertedComp'] > 80000) #countries from list 
df.loc[filt, ['Country', 'ConvertedComp', 'LanguageWorkedWith']]
# Out:
#             Country  ConvertedComp  \
# Respondent
# 44          Germany        87996.0
# 66          Germany       137490.0
# 143         Germany        93951.0
# 486          Poland        80150.0
# 558         Germany       120304.0
# ...             ...            ...
# 88381       Germany        80202.0
# 88462       Germany        82488.0
# 88518       Germany        80202.0
# 88751       Germany        91660.0
# 88861       Germany        97389.0
#
#                                            LanguageWorkedWith
# Respondent
# 44          Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# 66                  Clojure;Go;HTML/CSS;Java;JavaScript;R;SQL
# 143          C;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 486         Bash/Shell/PowerShell;HTML/CSS;JavaScript;Type...
# 558         Bash/Shell/PowerShell;C;HTML/CSS;Java;JavaScri...
# ...                                                       ...
# 88381       Bash/Shell/PowerShell;C;C++;Java;JavaScript;Py...
# ...

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)
df.loc[filt, 'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object
